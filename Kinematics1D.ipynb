# %%
from PhysicsOneA import *
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Chapter 3 - Physics Problems

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Graph Analysis**: A velocity vs. time graph showing wolf movement with points A-H marked.

# %% [markdown]
# ## Problem 1 - Wolf GPS Tracking

# %% [markdown]
# ### Questions:
# 1. **In which of the marked points (A-H) does the wolf not move?**
#    - A) Only E
#    - B) A, E and H
#    - C) C and F
#    - D) None of the marked points, the wolf is constantly moving
#    - E) Don't know

# %% [markdown]
# *Answer:* From reading the graph we can conclude that the wolf does not move in the points *A,E,H*. So the answer is *B)*

# %% [markdown]
# 2. **In which of the marked points (A-H) does the wolf not accelerate?**
#    - A) Only E
#    - B) A, E and H
#    - C) C and F
#    - D) In all points, the wolf never accelerates
#    - E) Don't know

# %% [markdown]
# *Answer:* from looking at the graph, the answer is *C)*

# %% [markdown]
# 3. **In which time intervals does the wolf approximately move at constant acceleration?**
#    - A) A-B
#    - B) B-C
#    - C) D-E and G-H
#    - D) C-D and E-F
#    - E) B-C and F-G
#    - F) Don't know

# %% [markdown]
# *Answer:* Looking at the graph again, the answer is *C)*

# %% [markdown]
# 4. **At what time is the wolf furthest away from the starting point at t = 0 s?**
#    - A) C
#    - B) E
#    - C) F
#    - D) H
#    - E) Don't know

# %% [markdown]
# *Answer:* *b)*

# %% [markdown]
# ## Problem 2 - Particle Motion Analysis

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Question:
# **Which of the graphs (A, B, C) fits with the motion of the particle?**
# - A) A
# - B) B
# - C) C
# - D) None of the graphs fits the motion of the particle
# - E) Don't know

# %% [markdown]
# *Answer:* *A)*

# %% [markdown]
# ## Problem 3 - Car Position Graph

# %% [markdown]
# **Graph**: Position vs. time graph for a car with points A-E marked.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Question:
# **In which points (A, B, C, D and/or E) does the car slow down?**
# - A) A
# - B) B
# - C) C
# - D) D
# - E) E
# - F) This answer cannot be solved using the graph
# - G) Don't know

# %% [markdown]
# *Answer* *D & E*

# %% [markdown]
# ## Problem 4 - Car Collision Problem

# %% [markdown]
# **Setup**: Maximum braking acceleration = 8 m/s². Two cars driving toward each other at 88 km/h, brake when 85 m apart.

# %% [markdown]
# ### Sub-questions:

# %% [markdown]
# a) **Will the two cars crash?**

# %%
u = speed_converter(88,'km/h', 'm/s')
a = -8
v = 0
answer = solve_suvat(u=u,a=a,v=v)
answer
# Out:
# {'s': 37.34567901234568,
#  'u': 24.444444444444443,
#  'v': 0.0,
#  'a': -8.0,
#  't': 3.0555555555555554}

# %% [markdown]
# Since the cars are taveling towards each other, we have to take the breaking distance $s$ and multiply it by 2.

# %%
s = answer['s']
s = s*2
s
# Out:
# 74.69135802469135

# %% [markdown]
# *Answer:* The cars do not crash

# %% [markdown]
# b) **In case the cars crash, what are the relative velocity of the cars in the crash?**

# %% [markdown]
# *Answer:* The cars do not crash

# %% [markdown]
# c) **In case the cars do not crash, how far are they apart when they come to a stop?**

# %%
85-s
# Out:
# 10.308641975308646

# %% [markdown]
# d) **Sketch the distance as a function of time for both cars in the same coordinate system.**

# %%
plot_distance_vs_time_two_objects(u,a,u,a,85)

# %% [markdown]
# ## Problem 5 - Identical Cars Collision

# %% [markdown]
# **Setup**: Two identical cars driving toward each other at 50.0 km/h. When 100 m apart, each brakes with 5.00 m/s² acceleration.

# %% [markdown]
# ### Question:
# **Which of the following statements are correct?**
# - A) They stop when they are 17.6 meters from each other
# - B) They stop when they are 61.4 meters from each other
# - C) They stop when they are 80.7 meters from each other
# - D) They stop just in front of each other
# - E) They crash after 1.06 seconds
# - F) They crash after 18.9 seconds
# - G) They stand still after 1.14 seconds
# - H) They stand still after 2.78 seconds
# - I) Don't know

# %%
u = speed_converter(50,'km/h', 'm/s')
v = 0
a = -5
answer = solve_suvat(u=u,v=v,a=a)
answer
# Out:
# {'s': 19.290123456790123,
#  'u': 13.88888888888889,
#  'v': 0.0,
#  'a': -5.0,
#  't': 2.7777777777777777}

# %%
s = answer['s']
s = s*2
s
# Out:
# 38.58024691358025

# %%
100-s
# Out:
# 61.41975308641975

# %% [markdown]
# *Answer* *b)*

# %% [markdown]
# ## Problem 6 - Car and Pedestrian

# %% [markdown]
# **Setup**: Car driving at 95 km/h observes pedestrian 60 m ahead. Driver has 1.5 s reaction time, then brakes at 8.0 m/s².

# %% [markdown]
# ### Question:
# **When the car reaches the pedestrian:**
# - A) It has a speed of 0.0 km/h (It just manages to stop)
# - B) It has a speed of 69 km/h
# - C) It has a speed of 93 km/h
# - D) It does not reach the pedestrian
# - E) Don't know

# %% [markdown]
# first we figure out how far the driver gets in 1.5 seconds, and update our distance to the pedistrian

# %%
u = speed_converter(95, 'km/h', 'm/s')
remaining_distance = 60 - (1.5*u)
remaining_distance
# Out:
# 20.416666666666664

# %% [markdown]
# the car has 20.42 meters to the pedistrian

# %%
result = solve_suvat(
    s=20.42,
    u=26.39,  
    a=-8.0,
    v=None,
    t=None
)

final_speed = result['v']
final_speed
# Out:
# 19.227899001190952

# %%
speed_converter(final_speed, 'm/s', 'km/h')
# Out:
# 69.22043640428743

# %% [markdown]
# *Answer:* *b)*

# %% [markdown]
# ## Problem 7 - Particle Velocity Analysis

# %% [markdown]
# **Graph**: Velocity vs. time graph for a particle from t = 0 s to t = 8 s.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Question:
# **Which of the following statements are true?**
# - A) The position of the particle is greater at t = 8 s compared to t = 0 s
# - B) The particle does not at any point move with a speed greater than 5 m/s
# - C) From t = 0 s to t = 4 s the particle has moved 20 m
# - D) At a given time interval, the particle moves 5 m in negative direction
# - E) During the motion, the particle has an acceleration of +5 m/s² and -5 m/s²
# - F) Between t = 4 s and t = 5 s the particle is at rest
# - G) Don't know

# %% [markdown]
# *Answer:* from reading the graph, *A,D,E* are true

# %% [markdown]
# ## Problem 8 - Two Cars Starting Sequence

# %% [markdown]
# **Setup**: Two cars at rest. First car starts at t = 0 with acceleration a. Second car starts at t = T/2 with same acceleration.

# %% [markdown]
# ## Question:
# **How far, L, is the distance between the two cars at t = T?**
# - A) L = ½aT²
# - B) L = ¼aT²
# - C) L = ⅛aT²
# - D) L = ⅓aT²
# - E) L = ⅔aT²
# - F) L = ¾aT²
# - G) L = ⅜aT²
# - H) L = ⅝aT²
# - I) Don't know

# %% [markdown]
# ## Problem 8 Solution
#
# **Setup**: Two cars at rest. First car starts at $t = 0$ with acceleration $a$. Second car starts at $t = T/2$ with same acceleration $a$.
#
# **Find**: Distance $L$ between cars at $t = T$.
#
# ### Solution
#
# **Car 1** (starts at $t = 0$):
# $$s_1 = \frac{1}{2}aT^2$$
#
# **Car 2** (starts at $t = T/2$):
# - Time moving: $T - \frac{T}{2} = \frac{T}{2}$
# - Distance: $s_2 = \frac{1}{2}a\left(\frac{T}{2}\right)^2 = \frac{1}{2}a \cdot \frac{T^2}{4} = \frac{aT^2}{8}$
#
# **Distance between cars**:
# $$L = s_1 - s_2 = \frac{1}{2}aT^2 - \frac{aT^2}{8}$$
#
# $$L = \frac{4aT^2}{8} - \frac{aT^2}{8} = \frac{3aT^2}{8}$$
#
# **Answer: G) $L = \frac{3}{8}aT^2$**

# %% [markdown]
# ## Problem 9 - RC Car Optimization

# %% [markdown]
# **Setup**: RC car travels 500m. Acceleration = 1.00 m/s², braking = 2.00 m/s², max speed = 10 m/s. Must start and end at rest.

# %% [markdown]
# ### Sub-questions:
# a) **Draw a graph of the velocity of the car as a function of time.**

# %% [markdown]
# Just draw it by hand, `PhsycisOneA` does not conver this functionality

# %% [markdown]
# b) **How long does it take the car to travel the distance?**

# %%
# Phase 1: Acceleration (0 to 10 m/s)
phase1 = solve_suvat(u=0, v=10, a=1.0)
   
# Phase 3: Braking (10 to 0 m/s) 
phase3 = solve_suvat(u=10, v=0, a=-2.0)
   
# Phase 2: Constant speed
remaining_distance = 500 - phase1['s'] - phase3['s']
phase2_time = remaining_distance / 10
   
total_time = phase1['t'] + phase2_time + phase3['t']
total_time
# Out:
# 57.5

# %% [markdown]
# *Answer* 57.5 seconds

# %% [markdown]
# ## Problem 10 - Bouncing Ball

# %% [markdown]
# **Setup**: Boy throws bouncy ball vertically downward with speed v₀ from height h₀. Ball doesn't lose energy, reaches height h₁ after bounce.

# %% [markdown]
# ### Question:
# **At what speed, v₀, was the ball thrown?**
# - A) v₀ = √(2gh₀)
# - B) v₀ = √(2gh₁)
# - C) v₀ = √(4gh₀)
# - D) v₀ = √(2g(h₁ - h₀))
# - E) v₀ = √(2g(h₁ + h₀))
# - F) Don't know

# %% [markdown]
# Just do it by hand, `PhsycisOneA` does not conver this functionality

# %% [markdown]
# ## Problem 11 - Athletic Jump Analysis

# %% [markdown]
# **Setup**: Understanding why athletes appear to "hang" in the air during vertical jumps of height h.

# %% [markdown]
# ### Question:
# a) **What fraction of the jump is the athlete in the height y > h/2?**

# %% [markdown]
# Just do it by hand, `PhsycisOneA` does not conver this functionality

# %% [markdown]
# ## Problem 12 - Earth Tunnel Problem

# %% [markdown]
# **Setup**: Cross-section of Earth with radius R. Tunnel connects North and South poles.

# %% [markdown]
# ### Sub-questions:

# %% [markdown]
# a) **Assuming gravity through earth is constant g, what would the speed of a stone dropped from the North Pole be as it crosses the center of the earth?**

# %%
g = gravity()
result = solve_suvat(u=0, s=R, a=g)
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 2
#       1 g = gravity()
# ----> 2 result = solve_suvat(u=0, s=R, a=g)
#       3 result
#
# NameError: name 'R' is not defined

# %% [markdown]
# Since R is not known, we cannot use the function to solve this question

# %% [markdown]
# b) **If gravity depends on position as a = -(x/R)g, and using the given derivation a = v(dv/dx), what is the stone's speed when it reaches the center of the earth?**

# %% [markdown]
# Just do it by hand, `PhsycisOneA` does not conver this functionality
